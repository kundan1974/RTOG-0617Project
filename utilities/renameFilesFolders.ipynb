# %%
import os
from os import path

# %%
pathS = "C:\\Users\\Kundan\\OneDrive\\matlabwork\\QARC_ESO_Project\\CroppedCERRDICOMfiles"
#output_path = "C:\\Users\\Admin\\OneDrive\\matlabwork\\QARC_ESO_Project\\npyImgs4CNN\\"
myfolders = []
for filename in os.listdir(pathS):
    if os.path.isfile(os.path.join(pathS,filename)):
        print(f"{filename} is not a directory")
    else:
        myfolders.append(os.path.join(pathS,filename))
# Out:
# batch_convert_results.xls is not a directory

# %%
for i in range(0,len(myfolders)):
    print(myfolders[i])
    print(myfolders[i][0:81])
# Out:
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\127856_PreRx_PET
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\127856
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\128048_PreRx_PET
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\128048
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\128813_PreRx_PET
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\128813
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\129143
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\129143
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\130498_PreRx_PET
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\130498
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\131819_10mm
# ...

# %%
for i in range(0,len(myfolders)):
    os.rename(myfolders[i],myfolders[i][0:81])
    print(myfolders[i])
    print(myfolders[i][0:81])
# Out:
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\127856_PreRx_PET
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\127856
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\128048_PreRx_PET
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\128048
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\128813_PreRx_PET
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\128813
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\129143
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\129143
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\130498_PreRx_PET
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\130498
# C:\Users\Kundan\OneDrive\matlabwork\QARC_ESO_Project\CroppedCERRDICOMfiles\131819_10mm
# ...

# %%
pathS = "C:\\Users\\Kundan\\OneDrive\\Eso_analysis\\AllCTData\\150247_PreRx_PET"
#output_path = "C:\\Users\\Admin\\OneDrive\\matlabwork\\QARC_ESO_Project\\npyImgs4CNN\\"
myfolders = []
for filename in os.listdir(pathS):
    myfolders.append(os.path.join(pathS,filename))

# %%
for i in range(0,len(myfolders)-1):
        name1p = 'CT.150247.'
        name2p = myfolders[i][75:]
        name2replace = os.path.join(myfolders[i][0:65],name1p+name2p)
        os.replace(myfolders[i],name2replace)
